# %% [markdown]
# # PROBLEM 3.9

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.array([2.60, 2.75, 4.00, 2.25, 3.00, 1.67, 2.25, 3.40, 1.33, 3.50, 3.75, 2.67,
              2.75, 2.00, 2.75, 2.50, 3.55, 2.75, 3.50, 2.75, 3.00, 3.25, 3.30, 2.75,
              3.75, 2.75, 3.00, 1.75, 2.75, 1.33, 0.67, 2.25, 1.75, 3.25, 1.75, 3.00,
              3.00, 3.00, 3.25, 2.25, 1.00, 2.50, 3.00, 2.40, 2.00, 2.75, 2.67, 2.00,
              2.00, 1.67, 3.00, 1.50, 3.75, 0.67, 1.50, 4.00, 3.00, 2.33, 1.75, 3.00,
              3.75, 2.67, 3.50, 0.67, 2.25, 3.00, 3.50, 1.75, 1.00, 3.00, 1.00, 2.50,
              2.50, 3.75, 3.50, 1.00, 2.25, 1.00, 2.50, 2.75, 0.75, 1.30, 1.25, 1.50,
              3.00, 2.00, 2.00, 2.50])

# make plot
plt.hist(data, bins=[b for b in np.arange(.625,4,.25)], edgecolor='black', color='skyblue')
plt.title('GPA vs Frequency\nHistogram')
plt.xlabel('GPA')
plt.ylabel('Frequency')
plt.yticks([x for x in np.arange(15)])
plt.xticks([x for x in np.arange(.5,4.25,.25)])

# count mean, std.dev, data count
mean = np.mean(data)
std_dev = np.std(data)
data_len = len(data)

# put mean, std.dev, data count on plot
plt.text(3.25,13, f"mean = {mean:.2f}")
plt.text(3.25,12, f"std. dev = {std_dev:.2f}")
plt.text(3.25,11, f"data length = {data_len}")

plt.show()
